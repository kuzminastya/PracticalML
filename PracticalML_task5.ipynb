# %%
import gym

# %%
env = gym.make('MountainCar-v0')
# done = 1, if
# 1) The car position is more than 0.5
# 2) Episode length is greater than 200

# %%
env.observation_space
# Out:
# Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)

# %%
env.action_space
# Out:
# Discrete(3)

# %%
import time
env.reset()
for i in range(1000):
    env.render()
    new_state, reward, done, _ = env.step(env.action_space.sample()) # take a random action
#     print(reward)
    if done:  
        break
env.close()

# %%
NA, NS = 3, 2

# %%
from keras import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.activations import relu, linear

model = Sequential()
model.add(Dense(64, input_dim=NS, activation=relu))
model.add(Dense(64, activation=relu))
model.add(Dense(NA, activation=linear))
model.compile(loss='mse', optimizer=Adam(0.001))

# %%
import numpy as np

epsilon = 1.0
epsilon_decay = 0.998

def choose_action(state):
    if np.random.rand() <= epsilon:
        return random.randrange(NA)
    qs = model.predict(state)
    return np.argmax(qs[0])

# %%
import random
from collections import deque

memory = deque() # tuples (state, action, reward, next state, done)
batch_size = 64

gamma = 0.99 # discount factor

def update_model():
    global epsilon, epsilon_decay 
    if len(memory) < batch_size:
        return
    
    batch = random.sample(memory, batch_size)
    states = np.squeeze(np.array([i[0] for i in batch]))
    actions = np.array([i[1] for i in batch])
    rewards = np.array([i[2] for i in batch])
    next_states = np.squeeze(np.array([i[3] for i in batch]))
    dones = np.array([i[4] for i in batch])
    
    targets = model.predict_on_batch(states)
    targets[[i for i in range(len(actions))], [actions]] = rewards + gamma*(np.amax(model.predict_on_batch(next_states), axis=1))*(1-dones)
    
    model.fit(states, targets, epochs=1, verbose=0)
    if epsilon > 0.01:
        epsilon *= epsilon_decay

# %%
# %%time
scores = []
for e in range(400):
    state = np.reshape(env.reset(), (1,2))
    score = 0
    for i in range(3000):
        action = choose_action(state)
        env.render()
        next_state, reward, done, _ = env.step(action)
        score += reward
        next_state = np.reshape(next_state, (1, 2))
        memory.append((state, action, reward, next_state, done))
        state = next_state
        update_model()
        if done:
            print("episode {} step {} => score {}".format(e, i, score))
            break
        scores.append(score)

        if np.mean(scores[-100:]) > 200:
            print("converged!")
            break
# Out:
# episode 0 step 199 => score -200.0
# episode 1 step 199 => score -200.0
# episode 2 step 199 => score -200.0
# episode 3 step 199 => score -200.0
# episode 4 step 199 => score -200.0
# episode 5 step 199 => score -200.0
# episode 6 step 199 => score -200.0
# episode 7 step 199 => score -200.0
# episode 8 step 199 => score -200.0
# episode 9 step 199 => score -200.0
# episode 10 step 199 => score -200.0
# episode 11 step 199 => score -200.0
# episode 12 step 199 => score -200.0
# episode 13 step 199 => score -200.0
# episode 14 step 199 => score -200.0
# episode 15 step 199 => score -200.0
# episode 16 step 199 => score -200.0
# episode 17 step 199 => score -200.0
# episode 18 step 199 => score -200.0
# episode 19 step 199 => score -200.0
# episode 20 step 199 => score -200.0
# episode 21 step 199 => score -200.0
# episode 22 step 199 => score -200.0
# episode 23 step 199 => score -200.0
# episode 24 step 199 => score -200.0
# episode 25 step 199 => score -200.0
# episode 26 step 199 => score -200.0
# episode 27 step 199 => score -200.0
# episode 28 step 199 => score -200.0
# episode 29 step 199 => score -200.0
# episode 30 step 199 => score -200.0
# episode 31 step 199 => score -200.0
# episode 32 step 199 => score -200.0
# episode 33 step 199 => score -200.0
# episode 34 step 199 => score -200.0
# episode 35 step 199 => score -200.0
# episode 36 step 199 => score -200.0
# episode 37 step 199 => score -200.0
# episode 38 step 199 => score -200.0
# episode 39 step 199 => score -200.0
# episode 40 step 199 => score -200.0
# episode 41 step 199 => score -200.0
# episode 42 step 199 => score -200.0
# episode 43 step 199 => score -200.0
# episode 44 step 199 => score -200.0
# episode 45 step 199 => score -200.0
# episode 46 step 199 => score -200.0
# episode 47 step 199 => score -200.0
# episode 48 step 199 => score -200.0
# episode 49 step 199 => score -200.0
# episode 50 step 199 => score -200.0
# episode 51 step 199 => score -200.0
# episode 52 step 199 => score -200.0
# episode 53 step 199 => score -200.0
# episode 54 step 199 => score -200.0
# episode 55 step 199 => score -200.0
# episode 56 step 199 => score -200.0
# episode 57 step 199 => score -200.0
# episode 58 step 199 => score -200.0
# episode 59 step 199 => score -200.0
# episode 60 step 199 => score -200.0
# episode 61 step 199 => score -200.0
# episode 62 step 199 => score -200.0
# episode 63 step 199 => score -200.0
# episode 64 step 199 => score -200.0
# episode 65 step 199 => score -200.0
# episode 66 step 199 => score -200.0
# episode 67 step 199 => score -200.0
# episode 68 step 199 => score -200.0
# episode 69 step 199 => score -200.0
# episode 70 step 199 => score -200.0
# episode 71 step 199 => score -200.0
# episode 72 step 199 => score -200.0
# episode 73 step 199 => score -200.0
# episode 74 step 199 => score -200.0
# episode 75 step 199 => score -200.0
# episode 76 step 199 => score -200.0
# episode 77 step 199 => score -200.0
# episode 78 step 196 => score -197.0
# episode 79 step 199 => score -200.0
# episode 80 step 199 => score -200.0
# episode 81 step 199 => score -200.0
# episode 82 step 199 => score -200.0
# episode 83 step 199 => score -200.0
# episode 84 step 199 => score -200.0
# episode 85 step 199 => score -200.0
# episode 86 step 199 => score -200.0
# episode 87 step 199 => score -200.0
# episode 88 step 199 => score -200.0
# episode 89 step 199 => score -200.0
# episode 90 step 199 => score -200.0
# episode 91 step 199 => score -200.0
# episode 92 step 199 => score -200.0
# episode 93 step 199 => score -200.0
# episode 94 step 199 => score -200.0
# episode 95 step 199 => score -200.0
# episode 96 step 199 => score -200.0
# episode 97 step 199 => score -200.0
# episode 98 step 199 => score -200.0
# episode 99 step 199 => score -200.0
# episode 100 step 199 => score -200.0
# episode 101 step 199 => score -200.0
# episode 102 step 199 => score -200.0
# episode 103 step 199 => score -200.0
# episode 104 step 199 => score -200.0
# episode 105 step 199 => score -200.0
# episode 106 step 187 => score -188.0
# episode 107 step 199 => score -200.0
# episode 108 step 199 => score -200.0
# episode 109 step 199 => score -200.0
# episode 110 step 199 => score -200.0
# episode 111 step 199 => score -200.0
# episode 112 step 199 => score -200.0
# episode 113 step 139 => score -140.0
# episode 114 step 199 => score -200.0
# episode 115 step 134 => score -135.0
# episode 116 step 199 => score -200.0
# episode 117 step 199 => score -200.0
# episode 118 step 199 => score -200.0
# episode 119 step 162 => score -163.0
# episode 120 step 199 => score -200.0
# episode 121 step 199 => score -200.0
# episode 122 step 197 => score -198.0
# episode 123 step 199 => score -200.0
# episode 124 step 158 => score -159.0
# episode 125 step 199 => score -200.0
# episode 126 step 199 => score -200.0
# episode 127 step 171 => score -172.0
# episode 128 step 199 => score -200.0
# episode 129 step 199 => score -200.0
# episode 130 step 199 => score -200.0
# episode 131 step 143 => score -144.0
# episode 132 step 151 => score -152.0
# episode 133 step 199 => score -200.0
# episode 134 step 154 => score -155.0
# episode 135 step 145 => score -146.0
# episode 136 step 146 => score -147.0
# episode 137 step 108 => score -109.0
# episode 138 step 172 => score -173.0
# episode 139 step 162 => score -163.0
# episode 140 step 199 => score -200.0
# episode 141 step 199 => score -200.0
# episode 142 step 144 => score -145.0
# episode 143 step 160 => score -161.0
# episode 144 step 154 => score -155.0
# episode 145 step 150 => score -151.0
# episode 146 step 137 => score -138.0
# episode 147 step 171 => score -172.0
# episode 148 step 141 => score -142.0
# episode 149 step 143 => score -144.0
# episode 150 step 163 => score -164.0
# episode 151 step 93 => score -94.0
# episode 152 step 159 => score -160.0
# episode 153 step 164 => score -165.0
# episode 154 step 128 => score -129.0
# episode 155 step 146 => score -147.0
# episode 156 step 152 => score -153.0
# episode 157 step 149 => score -150.0
# episode 158 step 162 => score -163.0
# episode 159 step 168 => score -169.0
# episode 160 step 158 => score -159.0
# episode 161 step 146 => score -147.0
# episode 162 step 164 => score -165.0
# episode 163 step 198 => score -199.0
# episode 164 step 163 => score -164.0
# episode 165 step 105 => score -106.0
# episode 166 step 158 => score -159.0
# episode 167 step 153 => score -154.0
# episode 168 step 151 => score -152.0
# episode 169 step 145 => score -146.0
# episode 170 step 141 => score -142.0
# episode 171 step 162 => score -163.0
# episode 172 step 199 => score -200.0
# episode 173 step 199 => score -200.0
# episode 174 step 173 => score -174.0
# episode 175 step 179 => score -180.0
# episode 176 step 86 => score -87.0
# episode 177 step 172 => score -173.0
# episode 178 step 159 => score -160.0
# episode 179 step 159 => score -160.0
# episode 180 step 86 => score -87.0
# episode 181 step 182 => score -183.0
# episode 182 step 149 => score -150.0
# episode 183 step 162 => score -163.0
# episode 184 step 146 => score -147.0
# episode 185 step 137 => score -138.0
# episode 186 step 120 => score -121.0
# episode 187 step 152 => score -153.0
# episode 188 step 122 => score -123.0
# episode 189 step 154 => score -155.0
# episode 190 step 146 => score -147.0
# episode 191 step 199 => score -200.0
# episode 192 step 108 => score -109.0
# episode 193 step 158 => score -159.0
# episode 194 step 147 => score -148.0
# episode 195 step 130 => score -131.0
# episode 196 step 143 => score -144.0
# episode 197 step 199 => score -200.0
# episode 198 step 115 => score -116.0
# episode 199 step 130 => score -131.0
# episode 200 step 115 => score -116.0
# episode 201 step 152 => score -153.0
# episode 202 step 153 => score -154.0
# episode 203 step 152 => score -153.0
# episode 204 step 116 => score -117.0
# episode 205 step 169 => score -170.0
# episode 206 step 178 => score -179.0
# episode 207 step 177 => score -178.0
# episode 208 step 148 => score -149.0
# episode 209 step 120 => score -121.0
# episode 210 step 96 => score -97.0
# episode 211 step 146 => score -147.0
# episode 212 step 173 => score -174.0
# episode 213 step 172 => score -173.0
# episode 214 step 113 => score -114.0
# episode 215 step 133 => score -134.0
# episode 216 step 133 => score -134.0
# episode 217 step 148 => score -149.0
# episode 218 step 154 => score -155.0
# episode 219 step 167 => score -168.0
# episode 220 step 125 => score -126.0
# episode 221 step 166 => score -167.0
# episode 222 step 128 => score -129.0
# episode 223 step 101 => score -102.0
# episode 224 step 155 => score -156.0
# episode 225 step 165 => score -166.0
# episode 226 step 199 => score -200.0
# episode 227 step 114 => score -115.0
# episode 228 step 161 => score -162.0
# episode 229 step 138 => score -139.0
# episode 230 step 148 => score -149.0
# episode 231 step 132 => score -133.0
# episode 232 step 134 => score -135.0
# episode 233 step 118 => score -119.0
# episode 234 step 156 => score -157.0
# episode 235 step 115 => score -116.0
# episode 236 step 148 => score -149.0
# episode 237 step 166 => score -167.0
# episode 238 step 139 => score -140.0
# episode 239 step 141 => score -142.0
# episode 240 step 127 => score -128.0
# episode 241 step 167 => score -168.0
# episode 242 step 178 => score -179.0
# episode 243 step 199 => score -200.0
# episode 244 step 114 => score -115.0
# episode 245 step 149 => score -150.0
# episode 246 step 199 => score -200.0
# episode 247 step 159 => score -160.0
# episode 248 step 162 => score -163.0
# episode 249 step 155 => score -156.0
# episode 250 step 117 => score -118.0
# episode 251 step 144 => score -145.0
# episode 252 step 87 => score -88.0
# episode 253 step 116 => score -117.0
# episode 254 step 161 => score -162.0
# episode 255 step 143 => score -144.0
# episode 256 step 150 => score -151.0
# episode 257 step 157 => score -158.0
# episode 258 step 90 => score -91.0
# episode 259 step 117 => score -118.0
# episode 260 step 197 => score -198.0
# episode 261 step 150 => score -151.0
# episode 262 step 164 => score -165.0
# episode 263 step 155 => score -156.0
# episode 264 step 164 => score -165.0
# episode 265 step 114 => score -115.0
# episode 266 step 175 => score -176.0
# episode 267 step 117 => score -118.0
# episode 268 step 184 => score -185.0
# episode 269 step 129 => score -130.0
# episode 270 step 115 => score -116.0
# episode 271 step 179 => score -180.0
# episode 272 step 122 => score -123.0
# episode 273 step 158 => score -159.0
# episode 274 step 148 => score -149.0
# episode 275 step 159 => score -160.0
# episode 276 step 178 => score -179.0
# episode 277 step 185 => score -186.0
# episode 278 step 163 => score -164.0
# episode 279 step 146 => score -147.0
# episode 280 step 138 => score -139.0
# episode 281 step 107 => score -108.0
# episode 282 step 164 => score -165.0
# episode 283 step 145 => score -146.0
# episode 284 step 136 => score -137.0
# episode 285 step 117 => score -118.0
# episode 286 step 166 => score -167.0
# episode 287 step 170 => score -171.0
# episode 288 step 169 => score -170.0
# episode 289 step 153 => score -154.0
# episode 290 step 155 => score -156.0
# episode 291 step 110 => score -111.0
# episode 292 step 199 => score -200.0
# episode 293 step 122 => score -123.0
# episode 294 step 117 => score -118.0
# episode 295 step 140 => score -141.0
# episode 296 step 157 => score -158.0
# episode 297 step 114 => score -115.0
# episode 298 step 173 => score -174.0
# episode 299 step 90 => score -91.0
# episode 300 step 154 => score -155.0
# episode 301 step 86 => score -87.0
# episode 302 step 110 => score -111.0
# episode 303 step 138 => score -139.0
# episode 304 step 199 => score -200.0
# episode 305 step 158 => score -159.0
# episode 306 step 156 => score -157.0
# episode 307 step 117 => score -118.0
# episode 308 step 106 => score -107.0
# episode 309 step 111 => score -112.0
# episode 310 step 108 => score -109.0
# episode 311 step 158 => score -159.0
# episode 312 step 159 => score -160.0
# episode 313 step 120 => score -121.0
# episode 314 step 161 => score -162.0
# episode 315 step 127 => score -128.0
# episode 316 step 161 => score -162.0
# episode 317 step 188 => score -189.0
# episode 318 step 140 => score -141.0
# episode 319 step 169 => score -170.0
# episode 320 step 106 => score -107.0
# episode 321 step 199 => score -200.0
# episode 322 step 109 => score -110.0
# episode 323 step 199 => score -200.0
# episode 324 step 129 => score -130.0
# episode 325 step 167 => score -168.0
# episode 326 step 135 => score -136.0
# episode 327 step 128 => score -129.0
# episode 328 step 163 => score -164.0
# episode 329 step 128 => score -129.0
# episode 330 step 160 => score -161.0
# episode 331 step 149 => score -150.0
# episode 332 step 120 => score -121.0
# episode 333 step 168 => score -169.0
# episode 334 step 198 => score -199.0
# episode 335 step 156 => score -157.0
# episode 336 step 94 => score -95.0
# episode 337 step 171 => score -172.0
# episode 338 step 109 => score -110.0
# episode 339 step 194 => score -195.0
# episode 340 step 157 => score -158.0
# episode 341 step 135 => score -136.0
# episode 342 step 155 => score -156.0
# episode 343 step 140 => score -141.0
# episode 344 step 111 => score -112.0
# episode 345 step 102 => score -103.0
# episode 346 step 114 => score -115.0
# episode 347 step 165 => score -166.0
# episode 348 step 130 => score -131.0
# episode 349 step 165 => score -166.0
# episode 350 step 132 => score -133.0
# episode 351 step 98 => score -99.0
# episode 352 step 120 => score -121.0
# episode 353 step 136 => score -137.0
# episode 354 step 144 => score -145.0
# episode 355 step 158 => score -159.0
# episode 356 step 127 => score -128.0
# episode 357 step 157 => score -158.0
# episode 358 step 166 => score -167.0
# episode 359 step 118 => score -119.0
# episode 360 step 157 => score -158.0
# episode 361 step 166 => score -167.0
# episode 362 step 154 => score -155.0
# episode 363 step 113 => score -114.0
# episode 364 step 121 => score -122.0
# episode 365 step 197 => score -198.0
# episode 366 step 90 => score -91.0
# episode 367 step 149 => score -150.0
# episode 368 step 121 => score -122.0
# episode 369 step 120 => score -121.0
# episode 370 step 137 => score -138.0
# episode 371 step 129 => score -130.0
# episode 372 step 122 => score -123.0
# episode 373 step 121 => score -122.0
# episode 374 step 111 => score -112.0
# episode 375 step 118 => score -119.0
# episode 376 step 157 => score -158.0
# episode 377 step 190 => score -191.0
# episode 378 step 96 => score -97.0
# episode 379 step 175 => score -176.0
# episode 380 step 155 => score -156.0
# episode 381 step 197 => score -198.0
# episode 382 step 163 => score -164.0
# episode 383 step 144 => score -145.0
# episode 384 step 133 => score -134.0
# episode 385 step 139 => score -140.0
# episode 386 step 118 => score -119.0
# episode 387 step 199 => score -200.0
# episode 388 step 197 => score -198.0
# episode 389 step 139 => score -140.0
# episode 390 step 154 => score -155.0
# episode 391 step 123 => score -124.0
# episode 392 step 158 => score -159.0
# episode 393 step 183 => score -184.0
# episode 394 step 113 => score -114.0
# episode 395 step 96 => score -97.0
# episode 396 step 171 => score -172.0
# episode 397 step 97 => score -98.0
# episode 398 step 90 => score -91.0
# episode 399 step 99 => score -100.0
# Wall time: 13h 17min 45s
